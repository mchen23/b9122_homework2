# %%
from bs4 import BeautifulSoup
import urllib.request
#from urllib.request import Request

seed_url = "https://www8.gsb.columbia.edu"

urls = [seed_url]    #queue of urls to crawl
seen = [seed_url]    #stack of urls seen so far
opened = []          #we keep track of seen urls so that we don't revisit them

maxNumUrl = 10; #set the maximum number of urls to visit
print("Starting with url="+str(urls))
while len(urls) > 0 and len(opened) < maxNumUrl:
    # DEQUEUE A URL FROM urls AND TRY TO OPEN AND READ IT
    try:
        curr_url=urls.pop(0)
        print("num. of URLs in stack: %d " % len(urls))
        print("Trying to access= "+curr_url)
        req = urllib.request.Request(curr_url,headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urllib.request.urlopen(req).read()
        opened.append(curr_url)

    except Exception as ex:
        print("Unable to access= "+curr_url)
        print(ex)
        continue    #skip code below

    # IF URL OPENS, CHECK WHICH URLS THE PAGE CONTAINS
    # ADD THE URLS FOUND TO THE QUEUE url AND seen
    soup = BeautifulSoup(webpage)  #creates object soup
    # Put child URLs into the stack
    for tag in soup.find_all('a', href = True): #find tags with links
        childUrl = tag['href'] #extract just the link
        o_childurl = childUrl
        childUrl = urllib.parse.urljoin(seed_url, childUrl)
        print("seed_url=" + seed_url)
        print("original childurl=" + o_childurl)
        print("childurl=" + childUrl)
        print("seed_url in childUrl=" + str(seed_url in childUrl))
        print("Have we seen this childUrl=" + str(childUrl in seen))
        if seed_url in childUrl and childUrl not in seen:
            print("***urls.append and seen.append***")
            urls.append(childUrl)
            seen.append(childUrl)
        else:
            print("######")

print("num. of URLs seen = %d, and scanned = %d" % (len(seen), len(opened)))
print("List of seen URLs:")
for seen_url in seen:
    print(seen_url)
# Out:
# Starting with url=['https://www8.gsb.columbia.edu']
# num. of URLs in stack: 0
# Trying to access= https://www8.gsb.columbia.edu
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://home.gsb.columbia.edu
# childurl=https://home.gsb.columbia.edu
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/contact
# childurl=https://www8.gsb.columbia.edu/contact
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://business.givenow.columbia.edu/
# childurl=https://business.givenow.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu
# childurl=https://academics.gsb.columbia.edu
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/mba
# childurl=https://academics.gsb.columbia.edu/mba
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/emba
# childurl=https://academics.gsb.columbia.edu/emba
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/ms
# childurl=https://academics.gsb.columbia.edu/ms
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/phd
# childurl=https://academics.gsb.columbia.edu/phd
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/mendelson-center
# childurl=https://academics.gsb.columbia.edu/mendelson-center
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/predoctoral-research
# childurl=https://academics.gsb.columbia.edu/predoctoral-research
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research
# childurl=https://www8.gsb.columbia.edu/faculty-research
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/execed/
# childurl=https://www8.gsb.columbia.edu/execed/
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/alumni/
# childurl=https://www8.gsb.columbia.edu/alumni/
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/about-us
# childurl=https://www8.gsb.columbia.edu/about-us
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/recruiters
# childurl=https://www8.gsb.columbia.edu/recruiters
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research/centers-programs
# childurl=https://www8.gsb.columbia.edu/faculty-research/centers-programs
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/students
# childurl=https://www8.gsb.columbia.edu/students
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-staff
# childurl=https://www8.gsb.columbia.edu/faculty-staff
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/newsroom
# childurl=https://www8.gsb.columbia.edu/newsroom
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/about-us/campus-maps-directions
# childurl=https://www8.gsb.columbia.edu/about-us/campus-maps-directions
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu/
# childurl=https://academics.gsb.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research
# childurl=https://www8.gsb.columbia.edu/faculty-research
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://leading.gsb.columbia.edu/features/understanding-the-impact-of-breakthrough-technologies/
# childurl=https://leading.gsb.columbia.edu/features/understanding-the-impact-of-breakthrough-technologies/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://leading.gsb.columbia.edu/features/climate-week-nyc-cbs-experts-weigh-in-on-smart-incentives-solutions-in-the-fight-against-climate-change/
# childurl=https://leading.gsb.columbia.edu/features/climate-week-nyc-cbs-experts-weigh-in-on-smart-incentives-solutions-in-the-fight-against-climate-change/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://leading.gsb.columbia.edu/features/what-skills-should-finance-students-seek-to-acquire-in-school/
# childurl=https://leading.gsb.columbia.edu/features/what-skills-should-finance-students-seek-to-acquire-in-school/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/execed
# childurl=https://www8.gsb.columbia.edu/execed
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://execed.business.columbia.edu/programs/business-and-climate-journey-to-net-zero?utm_source=GSB-Homepage
# childurl=https://execed.business.columbia.edu/programs/business-and-climate-journey-to-net-zero?utm_source=GSB-Homepage
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://execed.business.columbia.edu/programs/edp?utm_source=GSB-Homepage
# childurl=https://execed.business.columbia.edu/programs/edp?utm_source=GSB-Homepage
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://execed.business.columbia.edu/programs/lyso?utm_source=GSB-Homepage
# childurl=https://execed.business.columbia.edu/programs/lyso?utm_source=GSB-Homepage
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://execed.business.columbia.edu/programs/eldp?utm_source=GSB-Homepage
# childurl=https://execed.business.columbia.edu/programs/eldp?utm_source=GSB-Homepage
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/alumni
# childurl=https://www8.gsb.columbia.edu/alumni
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://business.columbia.edu/about-us
# childurl=https://business.columbia.edu/about-us
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=#intro
# childurl=https://www8.gsb.columbia.edu#intro
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://leading.gsb.columbia.edu/features/columbia-business-engineering-schools-launch-new-degree-program-to-meet-changing-workforce-needs/
# childurl=https://leading.gsb.columbia.edu/features/columbia-business-engineering-schools-launch-new-degree-program-to-meet-changing-workforce-needs/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://leading.gsb.columbia.edu/
# childurl=https://leading.gsb.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/newsroom/
# childurl=https://www8.gsb.columbia.edu/newsroom/
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://manhattanville.gsb.columbia.edu/
# childurl=https://manhattanville.gsb.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/mba-students/returning-to-campus
# childurl=https://www8.gsb.columbia.edu/mba-students/returning-to-campus
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://business.columbia.edu/DEI
# childurl=https://business.columbia.edu/DEI
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://home.gsb.columbia.edu/
# childurl=https://home.gsb.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://academics.gsb.columbia.edu
# childurl=https://academics.gsb.columbia.edu
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research
# childurl=https://www8.gsb.columbia.edu/faculty-research
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/execed
# childurl=https://www8.gsb.columbia.edu/execed
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/alumni
# childurl=https://www8.gsb.columbia.edu/alumni
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/about-us
# childurl=https://www8.gsb.columbia.edu/about-us
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research/centers-programs
# childurl=https://www8.gsb.columbia.edu/faculty-research/centers-programs
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/students
# childurl=https://www8.gsb.columbia.edu/students
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/recruiters
# childurl=https://www8.gsb.columbia.edu/recruiters
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/corporate
# childurl=https://www8.gsb.columbia.edu/corporate
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://business.givenow.columbia.edu/#
# childurl=https://business.givenow.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-staff
# childurl=https://www8.gsb.columbia.edu/faculty-staff
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/newsroom
# childurl=https://www8.gsb.columbia.edu/newsroom
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/about-us/contact-columbia/careers-columbia
# childurl=https://www8.gsb.columbia.edu/about-us/contact-columbia/careers-columbia
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/contact
# childurl=https://www8.gsb.columbia.edu/contact
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://twitter.com/Columbia_Biz
# childurl=https://twitter.com/Columbia_Biz
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www.instagram.com/columbia_biz/
# childurl=https://www.instagram.com/columbia_biz/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www.facebook.com/columbiabusiness/
# childurl=https://www.facebook.com/columbiabusiness/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www.youtube.com/columbiabusiness
# childurl=https://www.youtube.com/columbiabusiness
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www.linkedin.com/school/columbia-business-school/
# childurl=https://www.linkedin.com/school/columbia-business-school/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=tel:+1-212-854-1100
# childurl=tel:+1-212-854-1100
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/about-us/campus-maps-directions
# childurl=https://www8.gsb.columbia.edu/about-us/campus-maps-directions
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=#
# childurl=https://www8.gsb.columbia.edu
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://cuit.columbia.edu/privacy-notice
# childurl=https://cuit.columbia.edu/privacy-notice
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# num. of URLs in stack: 17
# Trying to access= https://www8.gsb.columbia.edu/contact
# seed_url=https://www8.gsb.columbia.edu
# original childurl=#mMenuSearch
# childurl=https://www8.gsb.columbia.edu#mMenuSearch
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research
# childurl=http://www8.gsb.columbia.edu/faculty-research
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/faculty
# childurl=http://www8.gsb.columbia.edu/faculty-research/faculty
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/node/248
# childurl=http://www8.gsb.columbia.edu/faculty-research/node/248
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/faculty/publications
# childurl=http://www8.gsb.columbia.edu/faculty-research/faculty/publications
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/faculty-directory
# childurl=http://www8.gsb.columbia.edu/faculty-research/faculty-directory
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/cbs-directory/faculty-expertise
# childurl=http://www8.gsb.columbia.edu/cbs-directory/faculty-expertise
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/faculty/recruitment
# childurl=http://www8.gsb.columbia.edu/faculty-research/faculty/recruitment
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research/faculty/awards
# childurl=https://www8.gsb.columbia.edu/faculty-research/faculty/awards
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/accounting
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/accounting
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/economics
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/economics
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/finance
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/finance
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/management
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/management
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/marketing
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/marketing
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/faculty-research/divisions/seminars
# childurl=https://www8.gsb.columbia.edu/faculty-research/divisions/seminars
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/accounting/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/accounting/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/finance/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/finance/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/management/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/management/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/marketing/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/marketing/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/seminars
# childurl=http://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/seminars
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/research
# childurl=http://www8.gsb.columbia.edu/faculty-research/research
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/research/about-us
# childurl=http://www8.gsb.columbia.edu/faculty-research/research/about-us
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/research/resources
# childurl=http://www8.gsb.columbia.edu/faculty-research/research/resources
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/research/impact
# childurl=http://www8.gsb.columbia.edu/faculty-research/research/impact
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/research/archive
# childurl=http://www8.gsb.columbia.edu/faculty-research/research/archive
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-research/centers-programs
# childurl=http://www8.gsb.columbia.edu/faculty-research/centers-programs
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/caseworks/
# childurl=http://www8.gsb.columbia.edu/caseworks/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/faculty-staff/faculty-governance
# childurl=http://www8.gsb.columbia.edu/faculty-staff/faculty-governance
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs
# childurl=http://www8.gsb.columbia.edu/programs
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/
# childurl=http://www8.gsb.columbia.edu/programs/mba/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/benefits-features
# childurl=http://www8.gsb.columbia.edu/programs/mba/benefits-features
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/academics
# childurl=http://www8.gsb.columbia.edu/programs/mba/academics
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/student-life
# childurl=http://www8.gsb.columbia.edu/programs/mba/student-life
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/career-support
# childurl=http://www8.gsb.columbia.edu/programs/mba/career-support
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/admissions
# childurl=http://www8.gsb.columbia.edu/programs/mba/admissions
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/mba/financial-aid/
# childurl=http://www8.gsb.columbia.edu/programs/mba/financial-aid/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/programs/mba/connect/contact-admissions
# childurl=https://www8.gsb.columbia.edu/programs/mba/connect/contact-admissions
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/options-locations
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/options-locations
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/academics
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/academics
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/student-life
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/student-life
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/career-management
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/career-management
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/admissions
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/admissions
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/tuition
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/tuition
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/sponsorship
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/sponsorship
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/executive-mba/connect
# childurl=http://www8.gsb.columbia.edu/programs/executive-mba/connect
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/academics
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/academics
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/dissertations
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/dissertations
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/people
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/people
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/why-columbia-phd
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/why-columbia-phd
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/admissions
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/admissions
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/job-market
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/job-market
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/master-of-science
# childurl=http://www8.gsb.columbia.edu/programs/master-of-science
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/master-of-science/accounting-and-fundamental-analysis
# childurl=http://www8.gsb.columbia.edu/programs/master-of-science/accounting-and-fundamental-analysis
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://msba.engineering.columbia.edu/
# childurl=https://msba.engineering.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/master-of-science/financial-economics
# childurl=http://www8.gsb.columbia.edu/programs/master-of-science/financial-economics
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://mse.ieor.columbia.edu/
# childurl=https://mse.ieor.columbia.edu/
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://www8.gsb.columbia.edu/programs/master-of-science/marketing-science
# childurl=https://www8.gsb.columbia.edu/programs/master-of-science/marketing-science
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/master-of-science/student-life
# childurl=http://www8.gsb.columbia.edu/programs/master-of-science/student-life
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed
# childurl=http://www8.gsb.columbia.edu/execed
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed/program-finder
# childurl=http://www8.gsb.columbia.edu/execed/program-finder
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed/programs-for-organizations
# childurl=http://www8.gsb.columbia.edu/execed/programs-for-organizations
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed/catalog
# childurl=http://www8.gsb.columbia.edu/execed/catalog
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed/certificates
# childurl=http://www8.gsb.columbia.edu/execed/certificates
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed/forms/contact-us
# childurl=http://www8.gsb.columbia.edu/execed/forms/contact-us
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/execed/myaccount
# childurl=http://www8.gsb.columbia.edu/execed/myaccount
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson
# childurl=http://www8.gsb.columbia.edu/mendelson
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson
# childurl=http://www8.gsb.columbia.edu/mendelson
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/about
# childurl=http://www8.gsb.columbia.edu/mendelson/about
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/benefits
# childurl=http://www8.gsb.columbia.edu/mendelson/benefits
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/apply
# childurl=http://www8.gsb.columbia.edu/mendelson/apply
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/requirements
# childurl=http://www8.gsb.columbia.edu/mendelson/requirements
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/faq
# childurl=http://www8.gsb.columbia.edu/mendelson/faq
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/student-experiences
# childurl=http://www8.gsb.columbia.edu/mendelson/student-experiences
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/mendelson/faculty
# childurl=http://www8.gsb.columbia.edu/mendelson/faculty
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/pre-doctoral-research
# childurl=http://www8.gsb.columbia.edu/programs/pre-doctoral-research
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www.gsb.columbia.edu/mba-students
# childurl=http://www.gsb.columbia.edu/mba-students
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www.gsb.columbia.edu/mba-students
# childurl=http://www.gsb.columbia.edu/mba-students
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www.gsb.columbia.edu/emba-students
# childurl=http://www.gsb.columbia.edu/emba-students
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www.gsb.columbia.edu/emba-global
# childurl=http://www.gsb.columbia.edu/emba-global
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/current-students
# childurl=http://www8.gsb.columbia.edu/programs/doctoral-program/current-students
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/programs/master-of-science/current-students
# childurl=http://www8.gsb.columbia.edu/programs/master-of-science/current-students
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/admitted
# childurl=http://www8.gsb.columbia.edu/admitted
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/alumni
# childurl=http://www8.gsb.columbia.edu/alumni
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=http://www8.gsb.columbia.edu/articles
# childurl=http://www8.gsb.columbia.edu/articles
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us
# childurl=https://www8.gsb.columbia.edu/about-us
# seed_url in childUrl=True
# Have we seen this childUrl=True
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/mission-statement
# childurl=https://www8.gsb.columbia.edu/about-us/mission-statement
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/knowledge
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/knowledge
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/knowledge/academic-programs
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/knowledge/academic-programs
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/knowledge/faculty
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/knowledge/faculty
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/knowledge/research
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/knowledge/research
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/knowledge/core-curriculum
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/knowledge/core-curriculum
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/access
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/access
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/access/nyc
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/access/nyc
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/executives-in-residence
# childurl=https://www8.gsb.columbia.edu/about-us/executives-in-residence
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/executives-in-residence/history
# childurl=https://www8.gsb.columbia.edu/about-us/executives-in-residence/history
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/executives-in-residence/resources
# childurl=https://www8.gsb.columbia.edu/about-us/executives-in-residence/resources
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/executives-in-residence/Meet-the-Executives
# childurl=https://www8.gsb.columbia.edu/about-us/executives-in-residence/Meet-the-Executives
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/executives-in-residence/Senior-Advisors
# childurl=https://www8.gsb.columbia.edu/about-us/executives-in-residence/Senior-Advisors
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/executives-in-residence/Upcoming-Events
# childurl=https://www8.gsb.columbia.edu/about-us/executives-in-residence/Upcoming-Events
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/community
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/community
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/community/clusters-learning-teams
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/community/clusters-learning-teams
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/why-columbia-business-school/impact
# childurl=https://www8.gsb.columbia.edu/about-us/why-columbia-business-school/impact
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/theory-to-practice
# childurl=https://www8.gsb.columbia.edu/about-us/theory-to-practice
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/theory-to-practice/innovation
# childurl=https://www8.gsb.columbia.edu/about-us/theory-to-practice/innovation
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/theory-to-practice/master-classes
# childurl=https://www8.gsb.columbia.edu/about-us/theory-to-practice/master-classes
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/theory-to-practice/master-classes/industry-partners
# childurl=https://www8.gsb.columbia.edu/about-us/theory-to-practice/master-classes/industry-partners
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/theory-to-practice/executive-education
# childurl=https://www8.gsb.columbia.edu/about-us/theory-to-practice/executive-education
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/theory-to-practice/entrepreneurship
# childurl=https://www8.gsb.columbia.edu/about-us/theory-to-practice/entrepreneurship
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/history-future
# childurl=https://www8.gsb.columbia.edu/about-us/history-future
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=https://manhattanville.gsb.columbia.edu
# childurl=https://manhattanville.gsb.columbia.edu
# seed_url in childUrl=False
# Have we seen this childUrl=False
# ######
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/board
# childurl=https://www8.gsb.columbia.edu/about-us/board
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-inclusion
# childurl=https://www8.gsb.columbia.edu/about-us/diversity-equity-inclusion
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-inclusion/annual-report-2021
# childurl=https://www8.gsb.columbia.edu/about-us/diversity-equity-inclusion/annual-report-2021
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-inclusion/annual-report-2021/community-diversity
# childurl=https://www8.gsb.columbia.edu/about-us/diversity-equity-inclusion/annual-report-2021/community-diversity
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-inclusion/annual-report-2021/curriculum-classroom
# childurl=https://www8.gsb.columbia.edu/about-us/diversity-equity-inclusion/annual-report-2021/curriculum-classroom
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-inclusion/annual-report-2021/culture-climate
# childurl=https://www8.gsb.columbia.edu/about-us/diversity-equity-inclusion/annual-report-2021/culture-climate
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-and-inclusion/community-diversity
# childurl=https://www8.gsb.columbia.edu/about-us/diversity-equity-and-inclusion/community-diversity
# seed_url in childUrl=True
# Have we seen this childUrl=False
# ***urls.append and seen.append***
# seed_url=https://www8.gsb.columbia.edu
# original childurl=/about-us/diversity-equity-and-inclusion/curriculum-and-classroom-inclusion
# ...
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/electives
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/IEP
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/IEP/about
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/IEP/events
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/IEP/people
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/appliedmicro
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/economictheory
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/industorg
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/interecon
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/macrolunch
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/microlunch
# https://www8.gsb.columbia.edu/faculty-research/divisions/economics/seminars/money
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/faculty
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/curriculum
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/electives
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/curriculum/phd
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/phd
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/seminars
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/seminars/freelunch
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/seminars/finance
# https://www8.gsb.columbia.edu/faculty-research/divisions/finance/seminars/phd
# https://www8.gsb.columbia.edu/faculty-research/divisions/management
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/faculty
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/faculty/chair-letter
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/curriculum
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/curriculum/mba
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/curriculum/emba
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/curriculum/doctoral
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/curriculum/electives
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/seminars
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/doctoral
# https://www8.gsb.columbia.edu/faculty-research/divisions/management/doctoral/conference
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/faculty-research
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/faculty-research/letter-chair
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/curriculum
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/curriculum/phd
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/curriculum/executive-education
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/seminars
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/students
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/students/phd
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/conferences/don-lehmann-50th-anniversary
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/conferences/bigdata
# https://www8.gsb.columbia.edu/faculty-research/divisions/marketing/conferences/frontiers
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/about
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/seminars
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/faculty-research
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/data
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/data/backward-v
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/competitive-strategy/strategy-conference
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/decision-making-negotiations
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/decision-making-negotiations/about
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/decision-making-negotiations/faculty
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/decision-making-negotiations/publications
# https://www8.gsb.columbia.edu/faculty-research/divisions/cross-disciplinary-areas/decision-making-negotiations/research
# https://www8.gsb.columbia.edu/faculty-research/research
# https://www8.gsb.columbia.edu/faculty-research/research/about-us
# https://www8.gsb.columbia.edu/faculty-research/research/resources
# https://www8.gsb.columbia.edu/faculty-research/research/impact
# https://www8.gsb.columbia.edu/faculty-research/research/archive
# https://www8.gsb.columbia.edu/programs/pre-doctoral-research
# https://www8.gsb.columbia.edu/programs/pre-doctoral-research/summer-research-internship
# https://www8.gsb.columbia.edu/faculty-research/
# https://www8.gsb.columbia.edu/faculty-research/file/478
# https://www8.gsb.columbia.edu/articles/ideas-work/how-setbacks-spur-leaps-forward
# https://www8.gsb.columbia.edu/auth/login
# https://www8.gsb.columbia.edu/cart
# https://www8.gsb.columbia.edu#!
# https://www8.gsb.columbia.edu/search/gcse
# https://www8.gsb.columbia.edu#globalSearch
# https://www8.gsb.columbia.edu/home
# https://www8.gsb.columbia.edu/programs-for-organizations
# https://www8.gsb.columbia.edu/programs-by-topic
# https://www8.gsb.columbia.edu/all-programs
# https://www8.gsb.columbia.edu/certificates
# https://www8.gsb.columbia.edu/webinars
# https://www8.gsb.columbia.edu/about
# https://www8.gsb.columbia.edu#globalNav
# https://www8.gsb.columbia.edu/programs/edp
# https://www8.gsb.columbia.edu/programs/wil
# https://www8.gsb.columbia.edu/programs/ns
# https://www8.gsb.columbia.edu#overview
# https://www8.gsb.columbia.edu#design-and-development
# https://www8.gsb.columbia.edu#learning-approach
# https://www8.gsb.columbia.edu#our-portfolio-of-programs
# https://www8.gsb.columbia.edu#testimonials
# https://www8.gsb.columbia.edu#case-studies
# https://www8.gsb.columbia.edu#client-list
# https://www8.gsb.columbia.edu/landing-general-management
# https://www8.gsb.columbia.edu/landing-leadership
# https://www8.gsb.columbia.edu/landing-finance-and-investing
# https://www8.gsb.columbia.edu/landing-strategy-and-innovation
# https://www8.gsb.columbia.edu/landing-marketing
# https://www8.gsb.columbia.edu/landing-digital-business
# https://www8.gsb.columbia.edu/landing-negotiation-and-decision-making
# https://www8.gsb.columbia.edu/landing-corporate-governance
# https://www8.gsb.columbia.edu/landing-business-and-society
# https://www8.gsb.columbia.edu/online
# https://www8.gsb.columbia.edu/programs/cgp?i=a0H3p00000sbqRJEAY
# https://www8.gsb.columbia.edu/programs/fanpo?i=a0H3p00000up2OVEAY
# https://www8.gsb.columbia.edu/programs/dtho?i=a0H3p00000ubXZCEA2
# https://www8.gsb.columbia.edu/programs/vc?i=a0H3p00000sbqSqEAI
# https://www8.gsb.columbia.edu/covid19-safety-plans
# https://www8.gsb.columbia.edu/maps
# https://www8.gsb.columbia.edu#main-content
# https://www8.gsb.columbia.edu/alumni/lifetime-network
# https://www8.gsb.columbia.edu/alumni/lifetime-network/graduating-students
# https://www8.gsb.columbia.edu/alumni/lifetime-network/stay-connected
# https://www8.gsb.columbia.edu/alumni/lifetime-network/stay-connected/class-notes
# https://www8.gsb.columbia.edu/alumni/lifetime-network/stay-connected/in-memoriam
# https://www8.gsb.columbia.edu/alumni/lifetime-network/get-involved
# https://www8.gsb.columbia.edu/alumni/lifetime-network/get-involved/student-initiatives
# https://www8.gsb.columbia.edu/alumni/lifetime-network/get-involved/ambassador-program
# https://www8.gsb.columbia.edu/alumni/lifetime-network/get-involved/columbia-career-network
# https://www8.gsb.columbia.edu/alumni/lifetime-network/stay-connected/social-media
# https://www8.gsb.columbia.edu/alumni/alumni-clubs
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/domestic-clubs
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/international-clubs
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/affinity-clubs
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/club-leader-resources
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/club-leader-resources/events-and-speakers
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/club-leader-resources/marketing
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/club-leader-resources/geographic-profiles
# https://www8.gsb.columbia.edu/alumni/alumni-clubs/club-leader-resources/additional-club-leader-resources
# https://www8.gsb.columbia.edu/alumni/young-alumni-board
# https://www8.gsb.columbia.edu/alumni/young-alumni-board/2020-2021-young-alumni-board
# https://www8.gsb.columbia.edu/alumni/young-alumni-board/young-alumni-resources
# https://www8.gsb.columbia.edu/alumni/womens-circle
# https://www8.gsb.columbia.edu/alumni/womens-circle/resources-and-opportunities
# https://www8.gsb.columbia.edu/alumni/womens-circle/research-insights-and-spotlights
# https://www8.gsb.columbia.edu/alumni/alumni-benefits
# https://www8.gsb.columbia.edu/alumni/alumni-benefits/lifetime-email-forwarding
# https://www8.gsb.columbia.edu/alumni/alumni-benefits/go-back-class
# https://www8.gsb.columbia.edu/alumni/career-management
# https://www8.gsb.columbia.edu/alumni/alumni-benefits/additional-resources
# https://www8.gsb.columbia.edu/alumni/alumni-benefits/checklist
# https://www8.gsb.columbia.edu/alumni/career-management/resources
# https://www8.gsb.columbia.edu/alumni/career-management/resources/self
# https://www8.gsb.columbia.edu/alumni/career-management/resources/research
# https://www8.gsb.columbia.edu/alumni/career-management/resources/professional-branding
# https://www8.gsb.columbia.edu/alumni/career-management/resources/networking
# https://www8.gsb.columbia.edu/alumni/career-management/resources/interviewing-offers
# https://www8.gsb.columbia.edu/alumni/career-management/resources/professional-development
# https://www8.gsb.columbia.edu/alumni/career-management/resources/media-library
# https://www8.gsb.columbia.edu/alumni/career-management/resources/job-opportunities
# https://www8.gsb.columbia.edu/alumni/career-management/resources/team/cbs
# https://www8.gsb.columbia.edu/alumni/career-management/resources/recruiting
# https://www8.gsb.columbia.edu/alumni/career-management/resources/resources-faqs
# https://www8.gsb.columbia.edu/alumni/support-school
# https://www8.gsb.columbia.edu/alumni/support-school/ways-give
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/1916-society
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/centennial-partners
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/student-relief-fund
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/hermes-society
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/recurring-gifts
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/second-century-circle
# https://www8.gsb.columbia.edu/alumni/support-school/annual-giving/student-philanthropy
# https://www8.gsb.columbia.edu/alumni/support-school/major-giving
# https://www8.gsb.columbia.edu/alumni/support-school/major-giving/student-financial-aid
# https://www8.gsb.columbia.edu/alumni/support-school/major-giving/faculty-and-research-support
# https://www8.gsb.columbia.edu/alumni/support-school/major-giving/founders-pledge
# https://www8.gsb.columbia.edu/alumni/support-school/major-giving/program-support
# https://www8.gsb.columbia.edu/alumni/support-school/planned-giving
# https://www8.gsb.columbia.edu/alumni/support-school/planned-giving/invest-your-future
# https://www8.gsb.columbia.edu/alumni/support-school/international-giving
# https://www8.gsb.columbia.edu/alumni/events
# https://www8.gsb.columbia.edu/alumni/events/events-calendar
# https://www8.gsb.columbia.edu/alumni/reunion
# https://www8.gsb.columbia.edu#more
# https://www8.gsb.columbia.edu/recruiters/how
# https://www8.gsb.columbia.edu/recruiters/how/order
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/calendars
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/calendars/full-time
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/calendars/internship
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/interview-logistics
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/interview-logistics/schedule-options
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/interview-logistics/request-dates
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/interview-logistics/student-policies
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/events
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/events/presentation-calendar-policies
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/events/request-schedule
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/events/facility-av-rental
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/events/summer
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/visiting-campus
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/visiting-campus/directions
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/visiting-campus/hotels
# https://www8.gsb.columbia.edu/recruiters/contact
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/visiting-campus/other-career
# https://www8.gsb.columbia.edu/recruiters/how/work-with-clubs
# https://www8.gsb.columbia.edu/recruiters/how/spread-word
# https://www8.gsb.columbia.edu/recruiters/how/international-hiring
# https://www8.gsb.columbia.edu/recruiters/how/on-campus-recruiting/interview-logistics/acceptable-interview-practices
# https://www8.gsb.columbia.edu/recruiters/who
# https://www8.gsb.columbia.edu/recruiters/who/interns
# https://www8.gsb.columbia.edu/recruiters/who/entry-level
# https://www8.gsb.columbia.edu/recruiters/who/associates-managers
# https://www8.gsb.columbia.edu/recruiters/who/senior-managers
# https://www8.gsb.columbia.edu/recruiters/why
# https://www8.gsb.columbia.edu/recruiters/why/training
# https://www8.gsb.columbia.edu/recruiters/why/student-body
# https://www8.gsb.columbia.edu/recruiters/why/entrepreneurial-minded
# https://www8.gsb.columbia.edu/recruiters/employmentreport
# https://www8.gsb.columbia.edu/recruiters/
# https://www8.gsb.columbia.edu/recruiters/file/105
# https://www8.gsb.columbia.edu/recruiters/sites/recruiters/files/CMC_Recruiting%20Experienced_2022_Sept_0.pdf
# https://www8.gsb.columbia.edu/recruiters/sites/recruiters/files/Recruiting%20Master%20of%20Science%20Students_2022.pdf
# https://www8.gsb.columbia.edu/recruiters/careeroffices
# https://www8.gsb.columbia.edu/recruiters/sites/recruiters/files/CMC_Recruiters%20Guide%202_FY22%20copy1024_1_3.jpg
# https://www8.gsb.columbia.edu/recruiters/sites/recruiters/files/calendar4%20%281%29.jpg
# https://www8.gsb.columbia.edu/recruiters/sites/recruiters/files/140-845_CBS_Employment_JL_v6.pdf
# https://www8.gsb.columbia.edu/fintech
# https://www8.gsb.columbia.edu/emba-students
# https://www8.gsb.columbia.edu/emba-global
# https://www8.gsb.columbia.edu/itg/get-help
